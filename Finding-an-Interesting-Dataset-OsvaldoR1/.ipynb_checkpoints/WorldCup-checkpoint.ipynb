# %%
import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

WorldCup_Data = pandas.read_csv("international_matches.csv")
WorldCup_Data.head(10)
# Out:
#          date      home_team     away_team home_team_continent  \
# 0  1993-08-08        Bolivia       Uruguay       South America
# 1  1993-08-08         Brazil        Mexico       South America
# 2  1993-08-08        Ecuador     Venezuela       South America
# 3  1993-08-08         Guinea  Sierra Leone              Africa
# 4  1993-08-08       Paraguay     Argentina       South America
# 5  1993-08-08           Peru      Colombia       South America
# 6  1993-08-08       Zimbabwe      Eswatini              Africa
# 7  1993-08-09         Guinea  Sierra Leone              Africa
# 8  1993-08-11  Faroe Islands        Norway              Europe
# 9  1993-08-11         Sweden   Switzerland              Europe
#
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0       South America                   59                   22
# 1       North America                    8                   14
# 2       South America                   35                   94
# 3              Africa                   65                   86
# 4       South America                   67                    5
# 5       South America                   70                   19
# 6              Africa                   50                  102
# 7              Africa                   65                   86
# 8              Europe                  111                    9
# 9              Europe                    4                    3
#
#    home_team_total_fifa_points  away_team_total_fifa_points  home_team_score  \
# 0                            0                            0                3
# 1                            0                            0                1
# 2                            0                            0                5
# 3                            0                            0                1
# 4                            0                            0                1
# 5                            0                            0                0
# 6                            0                            0                2
# 7                            0                            0                4
# 8                            0                            0                0
# 9                            0                            0                1
#
#    away_team_score                    tournament      city        country  \
# 0                1  FIFA World Cup qualification    La Paz        Bolivia
# 1                1                      Friendly    Maceió         Brazil
# 2                0  FIFA World Cup qualification     Quito        Ecuador
# 3                0                      Friendly   Conakry         Guinea
# 4                3  FIFA World Cup qualification  Asunción       Paraguay
# 5                1  FIFA World Cup qualification      Lima           Peru
# 6                0                      Friendly    Harare       Zimbabwe
# 7                0                      Friendly   Conakry         Guinea
# 8                7                      Friendly    Toftir  Faroe Islands
# 9                2                      Friendly     Borås         Sweden
#
#    neutral_location shoot_out home_team_result  home_team_goalkeeper_score  \
# 0             False        No              Win                         NaN
# 1             False        No             Draw                         NaN
# 2             False        No              Win                         NaN
# 3             False        No              Win                         NaN
# 4             False        No             Lose                         NaN
# 5             False        No             Lose                         NaN
# 6             False        No              Win                         NaN
# 7             False        No              Win                         NaN
# 8             False        No             Lose                         NaN
# 9             False        No             Lose                         NaN
#
#    away_team_goalkeeper_score  home_team_mean_defense_score  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
#
#    home_team_mean_offense_score  home_team_mean_midfield_score  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# 5                           NaN                            NaN
# 6                           NaN                            NaN
# 7                           NaN                            NaN
# 8                           NaN                            NaN
# 9                           NaN                            NaN
#
#    away_team_mean_defense_score  away_team_mean_offense_score  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# 6                           NaN                           NaN
# 7                           NaN                           NaN
# 8                           NaN                           NaN
# 9                           NaN                           NaN
#
#    away_team_mean_midfield_score
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN

# %%
WorldCup_Data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 WorldCup_Data.columns
#
# NameError: name 'WorldCup_Data' is not defined
